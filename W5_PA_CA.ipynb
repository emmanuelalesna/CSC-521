# %% [markdown]
# <a href="https://colab.research.google.com/github/emmanuelalesna/CSC-521/blob/main/W5_PA_CA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bogo Sort

# %%
import random
import time

# sorts array a[0..n-1] using Bogo sort
def bogoSort(a):
    n = len(a)
    while (not is_Sorted(a)):
        shuffle(a)
        print("Current array state: ", a)

# To check if array is sorted or not
def is_Sorted(a):
    n = len(a)
    for i in range(0, n-1):
        if (a[i] > a[i+1]):
            return False
    return True

# To generate permutation of the array
def shuffle(a):
    n = len(a)
    for i in range (n):
        r = random.randint(0, n-1)
        a[i], a[r] = a[r], a[i]

# Driver code to test above
a = [5, 2, 9, 1, 6]

start_time = time.perf_counter()
bogoSort(a)
end_time = time.perf_counter()
print("======================")
print("Sorted array: ")
print("".join(str(x) for x in a))
print("======================")
print("Time taken: ", end_time - start_time, "seconds")

# My example
b = [6, 5, 4, 3, 2, 1]
start_time = time.perf_counter()
bogoSort(b)
end_time = time.perf_counter()
print("======================")
print("Sorted array: ")
print("".join(str(x) for x in b))
print("======================")
print("Time taken: ", end_time - start_time, "seconds")
# Out:
# Current array state:  [2, 6, 1, 9, 5]
# Current array state:  [6, 5, 2, 1, 9]
# Current array state:  [9, 1, 6, 5, 2]
# Current array state:  [6, 2, 5, 1, 9]
# Current array state:  [5, 6, 9, 2, 1]
# Current array state:  [6, 1, 2, 9, 5]
# Current array state:  [2, 9, 1, 6, 5]
# Current array state:  [2, 6, 1, 9, 5]
# Current array state:  [5, 6, 1, 2, 9]
# Current array state:  [1, 5, 2, 6, 9]
# Current array state:  [5, 6, 2, 1, 9]
# Current array state:  [1, 6, 9, 2, 5]
# Current array state:  [6, 9, 1, 5, 2]
# Current array state:  [1, 2, 6, 9, 5]
# Current array state:  [1, 9, 2, 5, 6]
# Current array state:  [2, 5, 6, 1, 9]
# Current array state:  [5, 6, 9, 1, 2]
# Current array state:  [9, 1, 6, 5, 2]
# Current array state:  [1, 9, 2, 5, 6]
# Current array state:  [1, 5, 9, 6, 2]
# Current array state:  [6, 9, 5, 1, 2]
# Current array state:  [6, 5, 2, 9, 1]
# Current array state:  [9, 5, 2, 6, 1]
# Current array state:  [6, 5, 9, 2, 1]
# Current array state:  [2, 6, 1, 9, 5]
# ...

# %% [markdown]
# # Bubble Sort

# %%
def bubbleSort(arr):
    n = len(arr)
    # Traverse through all array elements
    for i in range(n):
        # Last i elements are already in place
        for j in range(0, n-i-1):
          # Traverse the array from 0 to n-i-1
          # Swap if the element found is greater than the next element
          if arr[j] > arr[j+1]:
              arr[j], arr[j+1] = arr[j+1], arr[j]
          # Print the array after each swap
          print("Step: ", arr)
        print("After pass ", i+1, ":", arr)
        print("")
    return arr

# Driver code to test above
arr = [5, 2, 9, 1, 6]
print("Original array: ", arr)
start_time = time.perf_counter()
sorted_arr = bubbleSort(arr)
end_time = time.perf_counter()
print("Sorted array: ", sorted_arr)
print("Time taken: ", end_time - start_time, "seconds")

# My example
b = [6, 5, 4, 3, 2, 1]
print("Original array: ", b)
start_time = time.perf_counter()
sorted_b = bubbleSort(b)
end_time = time.perf_counter()
print("Sorted array: ", sorted_b)
print("Time taken: ", end_time - start_time, "seconds")
# Out:
# Original array:  [5, 2, 9, 1, 6]
# Step:  [2, 5, 9, 1, 6]
# Step:  [2, 5, 9, 1, 6]
# Step:  [2, 5, 1, 9, 6]
# Step:  [2, 5, 1, 6, 9]
# After pass  1 : [2, 5, 1, 6, 9]
#
# Step:  [2, 5, 1, 6, 9]
# Step:  [2, 1, 5, 6, 9]
# Step:  [2, 1, 5, 6, 9]
# After pass  2 : [2, 1, 5, 6, 9]
#
# Step:  [1, 2, 5, 6, 9]
# Step:  [1, 2, 5, 6, 9]
# After pass  3 : [1, 2, 5, 6, 9]
#
# Step:  [1, 2, 5, 6, 9]
# After pass  4 : [1, 2, 5, 6, 9]
#
# After pass  5 : [1, 2, 5, 6, 9]
#
# Sorted array:  [1, 2, 5, 6, 9]
# Time taken:  0.0002043629999661789 seconds
# Original array:  [6, 5, 4, 3, 2, 1]
# Step:  [5, 6, 4, 3, 2, 1]
# Step:  [5, 4, 6, 3, 2, 1]
# Step:  [5, 4, 3, 6, 2, 1]
# Step:  [5, 4, 3, 2, 6, 1]
# Step:  [5, 4, 3, 2, 1, 6]
# After pass  1 : [5, 4, 3, 2, 1, 6]
#
# Step:  [4, 5, 3, 2, 1, 6]
# Step:  [4, 3, 5, 2, 1, 6]
# Step:  [4, 3, 2, 5, 1, 6]
# Step:  [4, 3, 2, 1, 5, 6]
# After pass  2 : [4, 3, 2, 1, 5, 6]
#
# Step:  [3, 4, 2, 1, 5, 6]
# Step:  [3, 2, 4, 1, 5, 6]
# Step:  [3, 2, 1, 4, 5, 6]
# ...

# %% [markdown]
# # Selection Sort

# %%
def selectionSort(arr):
  n = len(arr)
  # Traverse through all array elements
  for i in range(n):
    # Find the minimum element in remaining unsorted array
    min_idx = i
    for j in range(i+1, n):
      if arr[j] < arr[min_idx]:
        min_idx = j

    # Swap the found minimum element with the first element of the unsorted part
    arr[i], arr[min_idx] = arr[min_idx], arr[i]

    # Print the array after each iteration of selection sort
    print("After iteration: ", i+1, arr)
  return arr

# Driver code to test above
arr = [5, 2, 9, 1, 6]
print("Original array: ", arr)
start_time = time.perf_counter()
sorted_arr = selectionSort(arr)
end_time = time.perf_counter()
print("Sorted array: ", sorted_arr)
print("Time taken: ", end_time - start_time, "seconds")

# My example
b = [6, 5, 4, 3, 2, 1]
print("Original array: ", b)
start_time = time.perf_counter()
sorted_b = selectionSort(b)
end_time = time.perf_counter()
print("Sorted array: ", sorted_b)
print("Time taken: ", end_time - start_time, "seconds")
# Out:
# Original array:  [5, 2, 9, 1, 6]
# After iteration:  1 [1, 2, 9, 5, 6]
# After iteration:  2 [1, 2, 9, 5, 6]
# After iteration:  3 [1, 2, 5, 9, 6]
# After iteration:  4 [1, 2, 5, 6, 9]
# After iteration:  5 [1, 2, 5, 6, 9]
# Sorted array:  [1, 2, 5, 6, 9]
# Time taken:  0.00020236399996065302 seconds
# Original array:  [6, 5, 4, 3, 2, 1]
# After iteration:  1 [1, 5, 4, 3, 2, 6]
# After iteration:  2 [1, 2, 4, 3, 5, 6]
# After iteration:  3 [1, 2, 3, 4, 5, 6]
# After iteration:  4 [1, 2, 3, 4, 5, 6]
# After iteration:  5 [1, 2, 3, 4, 5, 6]
# After iteration:  6 [1, 2, 3, 4, 5, 6]
# Sorted array:  [1, 2, 3, 4, 5, 6]
# Time taken:  0.00022724400014340063 seconds
